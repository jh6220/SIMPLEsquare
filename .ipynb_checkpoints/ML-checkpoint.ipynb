# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import scipy.sparse as sparse
from scipy.sparse.linalg import spsolve
from sklearn.decomposition import PCA
from tqdm import tqdm
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense, Input, BatchNormalization
from tensorflow.keras.layers import Conv2D, Flatten, Conv1D
from tensorflow.keras.layers import Reshape, Conv2DTranspose
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import plot_model
from tensorflow.keras import backend as K
from scipy.signal import lfilter
import solverFunctions as sf
import analysisFunctions as af

# %%
x_train[:,:,:,2] = x_train[:,:,:,2] - np.expand_dims(x_train[:,:,:,2].mean((1,2)),axis=(1,2))
p = x_train[:,:,:,2]
plt.imshow(p[0,:,:])
plt.colorbar()
p.mean((1,2))
# Out:
# array([ 6.31593543e-17, -6.31593543e-17,  1.97372982e-17, ...,
#         1.89478063e-16, -6.31593543e-17,  0.00000000e+00])

# %%
def GetEncoder1(n_latent,input_shape):
    input_imag = Input(shape=input_shape, name='encoder_input')
    x = Flatten()(input_imag)
    latent = Dense(n_latent)(x)
    encoder = Model(input_imag,latent,name="encoder")
    return encoder

def GetDecoder(n_latent,input_shape):
    input_latent = Input(shape=(n_latent,))
    x = Dense(input_shape[0]*input_shape[1]*input_shape[2],use_bias=False)(input_latent)
    x = Reshape((input_shape[0],input_shape[1],input_shape[2]))(x)
    decoder = Model(input_latent,x,name="decoder")
    return decoder

def GetAE(input_shape,n_latent):
    input_imag = Input(shape=input_shape, name='encoder_input')
    encoder = GetEncoder1(n_latent,input_shape)
    decoder = GetDecoder(n_latent,input_shape)
    model = Model(input_imag, decoder(encoder(input_imag)))
    
    return model, encoder, decoder

# %%
# Out:
# array([2.67777417, 2.05892346, 1.59575849, ..., 2.24635836, 1.35578867,
#        1.9493145 ])

# %%
def getXtrain(order_bc):
    order_bc = 5
    u = np.load(r"DataDC/datasetDC_u_30_1_"+str(order_bc)+".npy")
    v = np.load(r"DataDC/datasetDC_v_30_1_"+str(order_bc)+".npy")
    p = np.load(r"DataDC/datasetDC_p_30_1_"+str(order_bc)+".npy")
    u_train = (u[:,1:,1:-1]+u[:,:-1,1:-1])/2
    u_train = np.expand_dims(u_train,axis=-1)
    v_train = (v[:,1:-1,1:]+v[:,1:-1,:-1])/2
    v_train = np.expand_dims(v_train,axis=-1)
    p_train = p
    p_train = np.expand_dims(p_train,axis=-1)
    x_train = np.concatenate([u_train,v_train,p_train],axis=3)
    return x_train

x_train = np.concatenate([getXtrain(2),getXtrain(5)],axis=0)
x_train2 = getXtrain(2)
x_train5 = getXtrain(5)
xRe_max = np.max(np.sqrt(x_train[:,:,:,0]**2+x_train[:,:,:,1]**2),axis=(1,2))
xRe_mean = np.mean(np.sqrt(x_train[:,:,:,0]**2+x_train[:,:,:,1]**2),axis=(1,2))
x_train.shape
# Out:
# (15850, 30, 30, 3)

# %%
np.isnan(x_train).any()
# Out:
# False

# %%
n_image = 30
n_latent = 9
model,encoder,decoder = GetAE((n_image,n_image,3),n_latent)
optimizer = tf.keras.optimizers.Adam(0.0002)
model.compile(loss='mse', optimizer=optimizer,metrics=['mse'])
history_l = model.fit(x_train,x_train,epochs=200,batch_size=32,validation_split=0.2,shuffle=True)
# Out:
# Epoch 1/200
# 397/397 [==============================] - 1s 3ms/step - loss: 1.9259 - mse: 1.9259 - val_loss: 0.6286 - val_mse: 0.6286
# Epoch 2/200
# 397/397 [==============================] - 1s 2ms/step - loss: 0.6129 - mse: 0.6129 - val_loss: 0.5936 - val_mse: 0.5936
# Epoch 3/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.5670 - mse: 0.5670 - val_loss: 0.5399 - val_mse: 0.5399
# Epoch 4/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.5134 - mse: 0.5134 - val_loss: 0.4857 - val_mse: 0.4857
# Epoch 5/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.4705 - mse: 0.4705 - val_loss: 0.4449 - val_mse: 0.4449
# Epoch 6/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.4293 - mse: 0.4293 - val_loss: 0.4083 - val_mse: 0.4083
# Epoch 7/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.3969 - mse: 0.3969 - val_loss: 0.3796 - val_mse: 0.3796
# Epoch 8/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.3690 - mse: 0.3690 - val_loss: 0.3554 - val_mse: 0.3554
# Epoch 9/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.3421 - mse: 0.3421 - val_loss: 0.3248 - val_mse: 0.3248
# Epoch 10/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.3098 - mse: 0.3098 - val_loss: 0.2951 - val_mse: 0.2951
# Epoch 11/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2827 - mse: 0.2827 - val_loss: 0.2774 - val_mse: 0.2774
# Epoch 12/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2673 - mse: 0.2673 - val_loss: 0.2632 - val_mse: 0.2632
# Epoch 13/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2566 - mse: 0.2566 - val_loss: 0.2547 - val_mse: 0.2547
# Epoch 14/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2486 - mse: 0.2486 - val_loss: 0.2479 - val_mse: 0.2479
# Epoch 15/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2400 - mse: 0.2400 - val_loss: 0.2373 - val_mse: 0.2373
# Epoch 16/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2303 - mse: 0.2303 - val_loss: 0.2307 - val_mse: 0.2307
# Epoch 17/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2261 - mse: 0.2261 - val_loss: 0.2284 - val_mse: 0.2284
# Epoch 18/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2253 - mse: 0.2253 - val_loss: 0.2273 - val_mse: 0.2273
# Epoch 19/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2235 - mse: 0.2235 - val_loss: 0.2274 - val_mse: 0.2274
# Epoch 20/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2238 - mse: 0.2238 - val_loss: 0.2265 - val_mse: 0.2265
# Epoch 21/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2236 - mse: 0.2236 - val_loss: 0.2271 - val_mse: 0.2271
# Epoch 22/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2233 - mse: 0.2233 - val_loss: 0.2274 - val_mse: 0.2274
# Epoch 23/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2237 - mse: 0.2237 - val_loss: 0.2261 - val_mse: 0.2261
# Epoch 24/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2233 - mse: 0.2233 - val_loss: 0.2268 - val_mse: 0.2268
# Epoch 25/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2373 - mse: 0.2373 - val_loss: 0.2263 - val_mse: 0.2263
# Epoch 26/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2232 - mse: 0.2232 - val_loss: 0.2276 - val_mse: 0.2276
# Epoch 27/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2231 - mse: 0.2231 - val_loss: 0.2278 - val_mse: 0.2278
# Epoch 28/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2230 - mse: 0.2230 - val_loss: 0.2262 - val_mse: 0.2262
# Epoch 29/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2231 - mse: 0.2231 - val_loss: 0.2263 - val_mse: 0.2263
# Epoch 30/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2229 - mse: 0.2229 - val_loss: 0.2266 - val_mse: 0.2266
# Epoch 31/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2230 - mse: 0.2230 - val_loss: 0.2261 - val_mse: 0.2261
# Epoch 32/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2235 - mse: 0.2235 - val_loss: 0.2418 - val_mse: 0.2418
# Epoch 33/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2253 - mse: 0.2253 - val_loss: 0.2264 - val_mse: 0.2264
# Epoch 34/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2228 - mse: 0.2228 - val_loss: 0.2301 - val_mse: 0.2301
# Epoch 35/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2230 - mse: 0.2230 - val_loss: 0.2263 - val_mse: 0.2263
# Epoch 36/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2229 - mse: 0.2229 - val_loss: 0.2266 - val_mse: 0.2266
# Epoch 37/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2240 - mse: 0.2240 - val_loss: 0.2405 - val_mse: 0.2405
# Epoch 38/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2229 - mse: 0.2229 - val_loss: 0.2260 - val_mse: 0.2260
# Epoch 39/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2229 - mse: 0.2229 - val_loss: 0.2260 - val_mse: 0.2260
# Epoch 40/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2289 - mse: 0.2289 - val_loss: 0.2261 - val_mse: 0.2261
# Epoch 41/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2226 - mse: 0.2226 - val_loss: 0.2259 - val_mse: 0.2259
# Epoch 42/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2228 - mse: 0.2228 - val_loss: 0.2260 - val_mse: 0.2260
# Epoch 43/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2225 - mse: 0.2225 - val_loss: 0.2260 - val_mse: 0.2260
# Epoch 44/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2226 - mse: 0.2226 - val_loss: 0.2259 - val_mse: 0.2259
# Epoch 45/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2229 - mse: 0.2229 - val_loss: 0.2260 - val_mse: 0.2260
# Epoch 46/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2300 - mse: 0.2300 - val_loss: 0.2262 - val_mse: 0.2262
# Epoch 47/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2228 - mse: 0.2228 - val_loss: 0.2259 - val_mse: 0.2259
# Epoch 48/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2225 - mse: 0.2225 - val_loss: 0.2262 - val_mse: 0.2262
# Epoch 49/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2227 - mse: 0.2227 - val_loss: 0.2261 - val_mse: 0.2261
# Epoch 50/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2225 - mse: 0.2225 - val_loss: 0.2261 - val_mse: 0.2261
# Epoch 51/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2229 - mse: 0.2229 - val_loss: 0.2260 - val_mse: 0.2260
# Epoch 52/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2230 - mse: 0.2230 - val_loss: 0.2266 - val_mse: 0.2266
# Epoch 53/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2229 - mse: 0.2229 - val_loss: 0.2266 - val_mse: 0.2266
# Epoch 54/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2260 - mse: 0.2260 - val_loss: 0.2266 - val_mse: 0.2266
# Epoch 55/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2247 - mse: 0.2247 - val_loss: 0.2265 - val_mse: 0.2265
# Epoch 56/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2226 - mse: 0.2226 - val_loss: 0.2272 - val_mse: 0.2272
# Epoch 57/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2227 - mse: 0.2227 - val_loss: 0.2261 - val_mse: 0.2261
# Epoch 58/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2225 - mse: 0.2225 - val_loss: 0.2293 - val_mse: 0.2293
# Epoch 59/200
# 397/397 [==============================] - 2s 4ms/step - loss: 0.2262 - mse: 0.2262 - val_loss: 0.2265 - val_mse: 0.2265
# Epoch 60/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2227 - mse: 0.2227 - val_loss: 0.2296 - val_mse: 0.2296
# Epoch 61/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2228 - mse: 0.2228 - val_loss: 0.2260 - val_mse: 0.2260
# Epoch 62/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2225 - mse: 0.2225 - val_loss: 0.2266 - val_mse: 0.2266
# Epoch 63/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2229 - mse: 0.2229 - val_loss: 0.2273 - val_mse: 0.2273
# Epoch 64/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2327 - mse: 0.2327 - val_loss: 0.2265 - val_mse: 0.2265
# Epoch 65/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2227 - mse: 0.2227 - val_loss: 0.2261 - val_mse: 0.2261
# Epoch 66/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2224 - mse: 0.2224 - val_loss: 0.2258 - val_mse: 0.2258
# Epoch 67/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2225 - mse: 0.2225 - val_loss: 0.2265 - val_mse: 0.2265
# Epoch 68/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2224 - mse: 0.2224 - val_loss: 0.2266 - val_mse: 0.2266
# Epoch 69/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2226 - mse: 0.2226 - val_loss: 0.2262 - val_mse: 0.2262
# Epoch 70/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2225 - mse: 0.2225 - val_loss: 0.2265 - val_mse: 0.2265
# Epoch 71/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2275 - mse: 0.2275 - val_loss: 0.2262 - val_mse: 0.2262
# Epoch 72/200
# 397/397 [==============================] - 1s 4ms/step - loss: 0.2226 - mse: 0.2226 - val_loss: 0.2260 - val_mse: 0.2260
# Epoch 73/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2224 - mse: 0.2224 - val_loss: 0.2257 - val_mse: 0.2257
# Epoch 74/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2225 - mse: 0.2225 - val_loss: 0.2260 - val_mse: 0.2260
# Epoch 75/200
# 397/397 [==============================] - 1s 4ms/step - loss: 0.2226 - mse: 0.2226 - val_loss: 0.2264 - val_mse: 0.2264
# Epoch 76/200
# 397/397 [==============================] - 1s 4ms/step - loss: 0.2225 - mse: 0.2225 - val_loss: 0.2264 - val_mse: 0.2264
# Epoch 77/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2427 - mse: 0.2427 - val_loss: 0.2330 - val_mse: 0.2330
# Epoch 78/200
# 397/397 [==============================] - 1s 4ms/step - loss: 0.2230 - mse: 0.2230 - val_loss: 0.2263 - val_mse: 0.2263
# Epoch 79/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2224 - mse: 0.2224 - val_loss: 0.2264 - val_mse: 0.2264
# Epoch 80/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2223 - mse: 0.2223 - val_loss: 0.2279 - val_mse: 0.2279
# Epoch 81/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2226 - mse: 0.2226 - val_loss: 0.2259 - val_mse: 0.2259
# Epoch 82/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2224 - mse: 0.2224 - val_loss: 0.2260 - val_mse: 0.2260
# Epoch 83/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2226 - mse: 0.2226 - val_loss: 0.2262 - val_mse: 0.2262
# Epoch
200
# 397/397 [==============================] - 1s 4ms/step - loss: 0.2230 - mse: 0.2230 - val_loss: 0.2259 - val_mse: 0.2259
# Epoch 171/200
# 397/397 [==============================] - 1s 4ms/step - loss: 0.2278 - mse: 0.2278 - val_loss: 0.2260 - val_mse: 0.2260
# Epoch 172/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2224 - mse: 0.2224 - val_loss: 0.2258 - val_mse: 0.2258
# Epoch 173/200
# 397/397 [==============================] - 1s 4ms/step - loss: 0.2228 - mse: 0.2228 - val_loss: 0.2259 - val_mse: 0.2259
# Epoch 174/200
# 397/397 [==============================] - 1s 4ms/step - loss: 0.2221 - mse: 0.2221 - val_loss: 0.2262 - val_mse: 0.2262
# Epoch 175/200
# 397/397 [==============================] - 1s 4ms/step - loss: 0.2224 - mse: 0.2224 - val_loss: 0.2267 - val_mse: 0.2267
# Epoch 176/200
# 397/397 [==============================] - 1s 4ms/step - loss: 0.2265 - mse: 0.2265 - val_loss: 0.2265 - val_mse: 0.2265
# Epoch 177/200
# 397/397 [==============================] - 1s 4ms/step - loss: 0.2225 - mse: 0.2225 - val_loss: 0.2262 - val_mse: 0.2262
# Epoch 178/200
# 397/397 [==============================] - 1s 4ms/step - loss: 0.2222 - mse: 0.2222 - val_loss: 0.2260 - val_mse: 0.2260
# Epoch 179/200
# 397/397 [==============================] - 2s 4ms/step - loss: 0.2222 - mse: 0.2222 - val_loss: 0.2261 - val_mse: 0.2261
# Epoch 180/200
# 397/397 [==============================] - 2s 4ms/step - loss: 0.2227 - mse: 0.2227 - val_loss: 0.2265 - val_mse: 0.2265
# Epoch 181/200
# 397/397 [==============================] - 2s 4ms/step - loss: 0.2222 - mse: 0.2222 - val_loss: 0.2270 - val_mse: 0.2270
# Epoch 182/200
# 397/397 [==============================] - 2s 4ms/step - loss: 0.2294 - mse: 0.2294 - val_loss: 0.2261 - val_mse: 0.2261
# Epoch 183/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2222 - mse: 0.2222 - val_loss: 0.2259 - val_mse: 0.2259
# Epoch 184/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2221 - mse: 0.2221 - val_loss: 0.2263 - val_mse: 0.2263
# Epoch 185/200
# 397/397 [==============================] - 1s 4ms/step - loss: 0.2221 - mse: 0.2221 - val_loss: 0.2259 - val_mse: 0.2259
# Epoch 186/200
# 397/397 [==============================] - 1s 4ms/step - loss: 0.2222 - mse: 0.2222 - val_loss: 0.2272 - val_mse: 0.2272
# Epoch 187/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2224 - mse: 0.2224 - val_loss: 0.2262 - val_mse: 0.2262
# Epoch 188/200
# 397/397 [==============================] - 1s 4ms/step - loss: 0.2229 - mse: 0.2229 - val_loss: 0.2264 - val_mse: 0.2264
# Epoch 189/200
# 397/397 [==============================] - 1s 4ms/step - loss: 0.2224 - mse: 0.2224 - val_loss: 0.2256 - val_mse: 0.2256
# Epoch 190/200
# 397/397 [==============================] - 1s 4ms/step - loss: 0.2263 - mse: 0.2263 - val_loss: 0.2278 - val_mse: 0.2278
# Epoch 191/200
# 397/397 [==============================] - 1s 4ms/step - loss: 0.2222 - mse: 0.2222 - val_loss: 0.2261 - val_mse: 0.2261
# Epoch 192/200
# 397/397 [==============================] - 1s 4ms/step - loss: 0.2222 - mse: 0.2222 - val_loss: 0.2264 - val_mse: 0.2264
# Epoch 193/200
# 397/397 [==============================] - 1s 4ms/step - loss: 0.2235 - mse: 0.2235 - val_loss: 0.2282 - val_mse: 0.2282
# Epoch 194/200
# 397/397 [==============================] - 1s 4ms/step - loss: 0.2411 - mse: 0.2411 - val_loss: 0.2259 - val_mse: 0.2259
# Epoch 195/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2222 - mse: 0.2222 - val_loss: 0.2265 - val_mse: 0.2265
# Epoch 196/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2222 - mse: 0.2222 - val_loss: 0.2263 - val_mse: 0.2263
# Epoch 197/200
# 397/397 [==============================] - 1s 3ms/step - loss: 0.2222 - mse: 0.2222 - val_loss: 0.2264 - val_mse: 0.2264
# Epoch 198/200
# 397/397 [==============================] - 1s 4ms/step - loss: 0.2221 - mse: 0.2221 - val_loss: 0.2259 - val_mse: 0.2259
# Epoch 199/200
# 397/397 [==============================] - 1s 4ms/step - loss: 0.2222 - mse: 0.2222 - val_loss: 0.2260 - val_mse: 0.2260
# Epoch 200/200
# 397/397 [==============================] - 1s 4ms/step - loss: 0.2223 - mse: 0.2223 - val_loss: 0.2262 - val_mse: 0.2262

# %%
plt.plot(history_l.history['mse'])
plt.plot(history_l.history['val_mse'])
plt.gca().set_yscale("log")
plt.legend(["train","validation"])

# %%
eig = decoder.trainable_variables[0].numpy().reshape(n_latent,30,30,3)
af.PlotX(3,3,eig,prob)
# Out:
# 100%|██████████| 9/9 [00:02<00:00,  4.09it/s]

# %%
indexes = np.arange(x_train.shape[0])
np.random.shuffle(indexes)
x_train = x_train[indexes]
x_sample = x_train[7007:]
x_recon = model(x_sample).numpy()
af.PlotX(2,2,x_sample,prob)
af.PlotX(2,2,x_recon,prob)
# Out:
# 100%|██████████| 4/4 [00:01<00:00,  2.66it/s]
# 100%|██████████| 4/4 [00:01<00:00,  3.48it/s]

# %%
def GetBoundary(x):
    if (len(x.shape)==4):
        u_n = x[:,:,:,0]
        v_n = x[:,:,:,1]
        u_bc = np.concatenate([u_n[:,:-1,0],u_n[:,-1,:-1],u_n[:,1:,-1][:,::-1],u_n[:,0,1:][:,::-1]],axis=-1)
        v_bc = np.concatenate([v_n[:,:-1,0],v_n[:,-1,:-1],v_n[:,1:,-1][:,::-1],v_n[:,0,1:][:,::-1]],axis=-1)
    else:
        u_n = x[:,:,0]
        v_n = x[:,:,1]
        u_bc = np.concatenate([u_n[:-1,0],u_n[-1,:-1],u_n[1:,-1][::-1],u_n[0,1:][::-1]])
        v_bc = np.concatenate([v_n[:-1,0],v_n[-1,:-1],v_n[1:,-1][::-1],v_n[0,1:][::-1]])
    return u_bc,v_bc

u_bc,v_bc = GetBoundary(eig)
plt.plot(np.transpose(u_bc))
plt.show()
plt.plot(np.transpose(v_bc))
plt.show()

# %%
mean = encoder(x_train[:]).numpy()
# plt.scatter(mean[:,0],mean[:,1])
pca = PCA(n_components=2)
pca_fit = pca.fit(mean)
points = pca_fit.transform(mean)
plt.scatter(points[:,0],points[:,1])

# %%
d = abs(points[:,0])+abs(points[:,1])
i = np.argmax(d)
i
# Out:
# 7008

# %%
def GetEncoderNL(n_latent,image):
    input_e = Input(image)
    x = Flatten()(input_e)
    x = Dense(100,activation='sigmoid')(x)
    x = BatchNormalization()(x)
    x = Dense(100,activation='sigmoid')(x)
    x = BatchNormalization()(x)
    mean = Dense(n_latent)(x)
    log_var = Dense(n_latent)(x)
    encoder = Model(input_e,[mean,log_var])
    return encoder

def GetDecoderNL(n_latent,image):
    input_d = Input(n_latent)
    x = Dense(100,activation='sigmoid')(input_d)
    x = BatchNormalization()(x)
    x = Dense(100,activation='sigmoid')(x)
    x = BatchNormalization()(x)
    x = Dense(image[0]*image[1]*image[2])(x)
    out_d = Reshape((image[0],image[1],image[2]))(x)
    decoder = Model(input_d,out_d)
    return decoder

def GetEncoderNL2(n_latent,image):
    input_e = Input(image)
    x = Conv2D(8,10,activation="sigmoid",strides=(2,2))(input_e)
    x = BatchNormalization()(x)
    x = Conv2D(16,10,activation="sigmoid",strides=(2,2))(x)
    x = BatchNormalization()(x)
    x = Flatten()(x)
    mean = Dense(n_latent)(x)
    log_var = Dense(n_latent)(x)
    encoder = Model(input_e,[mean,log_var])
    return encoder

def GetDecoderNL2(n_latent,image):
    input_d = Input(n_latent)
    x = Dense(20,activation='sigmoid')(input_d)
    x = BatchNormalization()(x)
    x = Dense(20,activation='sigmoid')(x)
    x = BatchNormalization()(x)
    x = Dense(image[0]*image[1])(x)
    out_d = Reshape((image[0],image[1],1))(x)
    decoder = Model(input_d,out_d)
    return decoder

def GetModelAENL(n_latent,image):
    encoder = GetEncoderNL(n_latent,image)
    decoder = GetDecoderNL(n_latent,image)
    model = Model(input_e,decoder(encoder(input_e)))
    return model,encoder,decoder

class ModelVAE_NL(Model):
    
    def __init__(self,n_latent,input):
        super(ModelVAE_NL,self).__init__()
        self.n_latent = n_latent
        self.encoder = GetEncoderNL(n_latent,input)
        self.decoder = GetDecoderNL(n_latent,input)
        
    def sample(self,z_mean,z_logsigma):
        batch, latent_dim = z_mean.shape
        epsilon = tf.random.normal(shape=(batch, latent_dim))
        z = z_mean + tf.math.exp(0.5 * z_logsigma) * epsilon
        return z
    
    def encode(self,x):
        mean, log_var = self.encoder(x)
        z = self.sample(mean,log_var)
        return z, mean, log_var
        
    def decode(self,z):
        x_r = self.decoder(z)
        return x_r
        
    def call(self,x):
        z, mean, log_var = self.encode(x)
        x_r = self.decode(z)
        return x_r, mean, log_var
    
    def reconstruct(self,x):
        mean,_ = self.encoder(x)
        x_r = self.decoder(mean)
        return x_r
    
class ModelVAE_NL2(Model):
    
    def __init__(self,n_latent,n_input):
        super(ModelVAE_NL2,self).__init__()
        self.n_latent = n_latent
        self.encoder = GetEncoderNL2(n_latent,(n_input,n_input,1))
        self.decoder = GetDecoderNL2(n_latent,(n_input,n_input,1))
        
    def sample(self,z_mean,z_logsigma):
        batch, latent_dim = z_mean.shape
        epsilon = tf.random.normal(shape=(batch, latent_dim))
        z = z_mean + tf.math.exp(0.5 * z_logsigma) * epsilon
        return z
    
    def encode(self,x):
        mean, log_var = self.encoder(x)
        z = self.sample(mean,log_var)
        return z, mean, log_var
        
    def decode(self,z):
        x_r = self.decoder(z)
        return x_r
        
    def call(self,x):
        z, mean, log_var = self.encode(x)
        x_r = self.decode(z)
        return x_r, mean, log_var
    
    def reconstruct(self,x):
        mean,_ = self.encoder(x)
        x_r = self.decoder(mean)
        return x_r
    
# def vae_loss_function(x, x_recon, mu, logsigma,kl_weight,A,fd_weight):
#     latent_loss = 0.5 * tf.reduce_sum(tf.exp(logsigma) + tf.square(mu) - 1.0 - logsigma, axis=1)
#     reconstruction_loss = tf.reduce_mean(tf.square(x-x_recon), axis=(1,2,3))
#     fd_loss = tf.reduce_mean(tf.square(tf.matmul(A,tf.reshape(x_recon,\
#         shape=(x_recon.shape[0],x_recon.shape[1]*x_recon.shape[2],1)))),axis=(1,2))
#     vae_loss = kl_weight * latent_loss + reconstruction_loss + fd_weight * fd_loss
#     return vae_loss,reconstruction_loss,latent_loss,fd_loss

def vae_loss_function(x, x_recon, mu, logsigma,kl_weight):
    latent_loss = 0.5 * tf.reduce_sum(tf.exp(logsigma) + tf.square(mu) - 1.0 - logsigma, axis=1)
    reconstruction_loss = tf.reduce_mean(tf.square(x-x_recon), axis=(1,2,3))
    vae_loss = kl_weight * latent_loss + reconstruction_loss
    return vae_loss,reconstruction_loss,latent_loss

@tf.function
def train_step_VAE(modelVAE,optimizer,images,kl_weight):
    with tf.GradientTape() as tape:
        
        (images_r, mu, log_vat) = modelVAE(images)
        images = tf.cast(images,tf.float32)
        loss,r_loss,l_loss = vae_loss_function(images,images_r, mu, log_vat,kl_weight)

    grads = tape.gradient(loss,modelVAE.trainable_variables)
    optimizer.apply_gradients(zip(grads,modelVAE.trainable_variables))
    return loss,r_loss,l_loss

class History():
    def __init__(self,n):
        self.loss = np.zeros(n)
        self.r_loss = np.zeros(n)
        self.l_loss = np.zeros(n)
        self.fd_loss = np.zeros(n)
        
    def add(self,history):
        self.loss = np.concatenate([self.loss,history.loss],axis=0)
        self.r_loss = np.concatenate([self.r_loss,history.r_loss],axis=0)
        self.l_loss = np.concatenate([self.l_loss,history.l_loss],axis=0)
        self.fd_loss = np.concatenate([self.fd_loss,history.fd_loss],axis=0)

def train_VAE(modelVAE,optimizer,x_train,n_epochs,n_batch,kl_weight=0.005):
    n_steps = n_epochs*len(range(0,x_train.shape[0],n_batch))
    history = History(n_steps)
    index = 0
    for epoch in range(n_epochs):
        i = np.arange(x_train.shape[0])
        np.random.shuffle(i)
        x_train = x_train[i,:,:,:]
#         x_train_shuffled = tf.cast(x_train_shuffled,tf.float32)

        for batch in range(0,x_train.shape[0],n_batch):
            loss,r_loss,l_loss = train_step_VAE(modelVAE,optimizer,x_train[batch:batch+n_batch],kl_weight)
            history.loss[index] = tf.reduce_mean(loss)
            history.r_loss[index] = tf.reduce_mean(r_loss)
            history.l_loss[index] = tf.reduce_mean(l_loss)
            # history.fd_loss[index] = tf.reduce_mean(fd_loss)
            
            print("\r{}/{} epochs - {:.3g}%; loss = {:.5g}".format(epoch+1,n_epochs, 100*batch/x_train.shape[0],history.loss[index]),end="\t") #
            index+=1
            
        print("\r{}/{} epochs - {:.3g}%; loss = {:.5g}".format(epoch+1,n_epochs, 100,history.loss[index-10:index-1].mean()),end="\t") #
            
    return history

# %%
n_batch = 128
n_epochs = 1000
kl_weight = 0.005 #kl_weight = 0.0005
n_latent = 10
input_shape = x_train[0].shape
lr = 0.001

# modelVAE = ModelVAE_NL(n_latent,input_shape)
# optimizer = tf.keras.optimizers.Adam(learning_rate=lr)

lhistory_part = train_VAE(modelVAE,optimizer,x_train,n_epochs,n_batch,kl_weight)
print()
if ('lhistory' in locals()):
    lhistory.add(lhistory_part)
    print("add")
else:
    lhistory = lhistory_part
    print("define")
# Out:
# 1000/1000 epochs - 100%; loss = 0.64942
# add

# %%
modelVAE.save_weights("MLmodels/NS_10D_NLv1")

# %%
modelVAE2 = ModelVAE_NL(n_latent,input_shape)
modelVAE2.load_weights("MLmodels/NS_10D_NLv1")

# %%
n_filt = 2000
a = np.ones(n_filt)
h = lfilter(a,a.sum(),lhistory.r_loss[:])
ax = plt.subplot()
ax.plot(h[n_filt:])
ax.set_yscale('log')
plt.xlabel("n steps")
plt.ylabel("loss")
# Out:
# Text(0, 0.5, 'loss')

# %%
index = 2000
mean,logvar=modelVAE.encoder(x_train[:index])
mean = mean.numpy()
a = mean.var(0)
i = np.where(a>0.1)
plt.scatter(mean[:,7],mean[:,8],c=xRe_max[:index])
# pca = PCA(n_components=2)
# pca_fit = pca.fit(mean)
# points = pca_fit.transform(mean)
# plt.scatter(points[:,0],points[:,1],c=xRe_mean[:index])
plt.colorbar()
a
# Out:
# array([1.6783084 , 1.1590276 , 1.5797187 , 2.1221259 , 1.6898253 ,
#        1.9641306 , 2.0054324 , 0.21444091, 0.25710285, 1.159873  ],
#       dtype=float32)

# %%
# np.exp(logvar.numpy().mean(0))
indexes = np.arange(x_train.shape[0])
np.random.shuffle(indexes)
x_train = x_train[indexes]
x_sample = x_train[:]
x_recon = modelVAE2.reconstruct(x_sample).numpy()
af.PlotX(4,4,x_sample,prob)
af.PlotX(4,4,x_recon,prob)
# Out:
# 100%|██████████| 16/16 [00:06<00:00,  2.29it/s]
# 100%|██████████| 16/16 [00:05<00:00,  2.91it/s]
